# %% [markdown]
# # LSTM

# %%
import pandas as pd
import numpy as np
import tensorflow as tf

# %%
from pandas_datareader import data
from google.colab import files
uploaded = files.upload()
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal
#      <input type="file" id="files-169759b9-398c-4673-b474-5fe944c3a353" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-169759b9-398c-4673-b474-5fe944c3a353">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Kuantan1975-2017New.csv to Kuantan1975-2017New.csv

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['Kuantan1975-2017New.csv']))
print(df,sep=',')
df.head()
# Out:
#                   Date  Year  Month  Day  KUANTAN[mm]
# 0        1/1/1975 0:00  1975      1    1          0.5
# 1        1/2/1975 0:00  1975      1    2        131.3
# 2        1/3/1975 0:00  1975      1    3         10.8
# 3        1/4/1975 0:00  1975      1    4        240.5
# 4        1/5/1975 0:00  1975      1    5         18.1
# ...                ...   ...    ...  ...          ...
# 15690  12/27/2017 0:00  2017     12   27          2.6
# 15691  12/28/2017 0:00  2017     12   28         20.6
# 15692  12/29/2017 0:00  2017     12   29         49.4
# 15693  12/30/2017 0:00  2017     12   30         14.4
# 15694  12/31/2017 0:00  2017     12   31         61.4
#
# [15695 rows x 5 columns]
#             Date  Year  Month  Day  KUANTAN[mm]
# 0  1/1/1975 0:00  1975      1    1          0.5
# 1  1/2/1975 0:00  1975      1    2        131.3
# 2  1/3/1975 0:00  1975      1    3         10.8
# 3  1/4/1975 0:00  1975      1    4        240.5
# 4  1/5/1975 0:00  1975      1    5         18.1

# %% [markdown]
# **With** **Normalization**

# %%
dataset = df.loc[:,'KUANTAN[mm]'].values
dataset = np.reshape(dataset,(-1,1))
print(dataset)
dataset.shape
# Out:
# [[  0.5]
#  [131.3]
#  [ 10.8]
#  ...
#  [ 49.4]
#  [ 14.4]
#  [ 61.4]]
# (15695, 1)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
print(dataset)
#train_size = int(len(dataset) * 0.80)
#test_size = len(dataset) - train_size
#train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
# Out:
# [[0.00094787]
#  [0.24890995]
#  [0.02047393]
#  ...
#  [0.09364929]
#  [0.02729858]
#  [0.1163981 ]]

# %%
#split into samples
from numpy import array

#14600/365 = 40
#sample = list(rain)

#split a univariate sequence into samples
def split_sequence(sequence, n_steps):
  x, y = list(), list()
  for i in range(len(sequence)):
    #find end of this pattern
    end_ix = i + n_steps
    #check if beyond the sequence
    if end_ix > len(sequence)-1:
      break
    #gather input and output parts of the pattern
    seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
    x.append(seq_x)
    y.append(seq_y)
  return array(x), array(y)

series = array(dataset)
print(series.shape)

x, y = split_sequence(series, 365)
print(x.shape, y.shape)
# Out:
# (15695, 1)
# (15330, 365, 1) (15330, 1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 0)
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (10731, 365, 1) (10731, 1)
# (4599, 365, 1) (4599, 1)

# %%
#reshape 
series1 = x_train.reshape(x_train.shape[0], x_train.shape[1], 1)
series2 = x_test.reshape(x_test.shape[0], x_test.shape[1], 1)
print(series1.shape)
print(series2.shape)
# Out:
# (10731, 365, 1)
# (4599, 365, 1)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense 
from keras.layers import Dropout
from keras.layers import LSTM
from keras.optimizers import SGD
import keras.backend as K
from keras.callbacks import EarlyStopping

# %% [markdown]
# **batch size for series1 = 2, 4, 53, 94, 106, 188, 2491, 4982**
#
# **batch size for series2 = 4271 is a prime number**

# %%
K.clear_session()
model = Sequential()
model.add(LSTM(16, input_shape=(365, 1)))
#model.add(LSTM(15))
#model.add(Dropout(0.1))
model.add(Dense(1))
#opt = keras.optimizers.Adam(learning_rate=1e-1000)
#opt = optimizers.adam(clipnorm=1.0)
#opt = SGD(lr=0.01, momentum=0.9, clipnorm=1.0)
model.compile(loss='mean_squared_error', optimizer='adam')


history = model.fit(series1, y_train, epochs=500, batch_size=200, validation_data=(series2, y_test),
                   callbacks=[EarlyStopping(monitor='val_loss', patience=10)], verbose=1, shuffle=False)

model.summary()
# Out:
# Train on 10731 samples, validate on 4599 samples
# Epoch 1/500
# 10731/10731 [==============================] - 12s 1ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 2/500
# 10731/10731 [==============================] - 12s 1ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 3/500
# 10731/10731 [==============================] - 12s 1ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 4/500
# 10731/10731 [==============================] - 12s 1ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 5/500
# 10731/10731 [==============================] - 12s 1ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 6/500
# 10731/10731 [==============================] - 12s 1ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 7/500
# 10731/10731 [==============================] - 12s 1ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 8/500
# 10731/10731 [==============================] - 12s 1ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 9/500
# 10731/10731 [==============================] - 12s 1ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 10/500
# 10731/10731 [==============================] - 12s 1ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 11/500
# 10731/10731 [==============================] - 12s 1ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 12/500
# 10731/10731 [==============================] - 12s 1ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 13/500
# 10731/10731 [==============================] - 12s 1ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 14/500
# 10731/10731 [==============================] - 12s 1ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 15/500
# 10731/10731 [==============================] - 12s 1ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 16/500
# 10731/10731 [==============================] - 12s 1ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 17/500
# 10731/10731 [==============================] - 12s 1ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 18/500
# 10731/10731 [==============================] - 12s 1ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 19/500
# 10731/10731 [==============================] - 12s 1ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 20/500
# 10731/10731 [==============================] - 12s 1ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 21/500
# 10731/10731 [==============================] - 12s 1ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 22/500
# 10731/10731 [==============================] - 12s 1ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 23/500
# 10731/10731 [==============================] - 12s 1ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 24/500
# 10731/10731 [==============================] - 12s 1ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 25/500
# 10731/10731 [==============================] - 12s 1ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 26/500
# 10731/10731 [==============================] - 12s 1ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 27/500
# 10731/10731 [==============================] - 12s 1ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 28/500
# 10731/10731 [==============================] - 12s 1ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 29/500
# 10731/10731 [==============================] - 12s 1ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 30/500
# 10731/10731 [==============================] - 12s 1ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 31/500
# 10731/10731 [==============================] - 12s 1ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 32/500
# 10731/10731 [==============================] - 12s 1ms/step - loss: 0.0014 - val_loss: 0.0016
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 16)                1152
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 1,169
# Trainable params: 1,169
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Make Predictions**

# %%
import math
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

train_predict = model.predict(series1)
test_predict = model.predict(series2)
# invert predictions
train_predict = scaler.inverse_transform(train_predict)
y_train = scaler.inverse_transform(y_train)
test_predict = scaler.inverse_transform(test_predict)
y_test = scaler.inverse_transform(y_test)

# %%
print('Train Mean Absolute Error:', mean_absolute_error(y_train[:,0], train_predict[:,0]))
print('Train Root Mean Squared Error:',np.sqrt(mean_squared_error(y_train[:,0], train_predict[:,0])))
print('Test Mean Absolute Error:', mean_absolute_error(y_test[:,0], test_predict[:,0]))
print('Test Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test[:,0], test_predict[:,0])))
# Out:
# Train Mean Absolute Error: 10.854363772520514
# Train Root Mean Squared Error: 19.711975544638133
# Test Mean Absolute Error: 10.834628840813716
# Test Root Mean Squared Error: 20.92153926073285

# %%
import matplotlib.pyplot as plt
#plot model loss

plt.figure(figsize=(8,4))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend(loc='upper right')
plt.show();

# %%
#actual vs prediction

import seaborn as sns

aa=[x for x in range(200)]
plt.figure(figsize=(12,6))
plt.plot(aa, y_test[:,0][:200], marker='.', label="actual")
plt.plot(aa, test_predict[:,0][:200], 'r', label="prediction")
# plt.tick_params(left=False, labelleft=True) #remove ticks
plt.tight_layout()
sns.despine(top=True)
plt.subplots_adjust(left=0.07)
plt.title('Kuala Krai Station', size=15)
plt.ylabel('Rainfall Amount (mm)', size=15)
plt.xlabel('Time step', size=15)
plt.legend(fontsize=15)
plt.show();

# %%
print(test_predict.shape)
print(y_test.shape)

a = plt.axes(aspect='equal')
plt.scatter(y_test, test_predict)
plt.xlabel('True Values')
plt.ylabel('Predictions')
lims = [0, 320]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)
# Out:
# (4599, 1)
# (4599, 1)

# %%
import scipy.stats as measures

per_coef = measures.pearsonr(y_test[:,0], test_predict[:,0])
#mse_coef = np.mean(np.square(np.array(y_pred) - np.array(y_true)))
print(per_coef)
# Out:
# (0.32345981511554095, 1.7460986261854386e-112)

# %%
per_coef1 = measures.pearsonr(y_train[:,0], train_predict[:,0])
print(per_coef1)
# Out:
# (0.3352444619156171, 3.9986122222896024e-280)

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# # Stacked LSTM

# %%
import pandas as pd
import numpy as np
import tensorflow as tf

# %%
from pandas_datareader import data
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e38516b9-1467-4541-99fb-511638390d96" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e38516b9-1467-4541-99fb-511638390d96">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Kuantan1975-2017New.csv to Kuantan1975-2017New.csv

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['Kuantan1975-2017New.csv']))
print(df,sep=',')
df.head()
# Out:
#                   Date  Year  Month  Day  KUANTAN[mm]
# 0        1/1/1975 0:00  1975      1    1          0.5
# 1        1/2/1975 0:00  1975      1    2        131.3
# 2        1/3/1975 0:00  1975      1    3         10.8
# 3        1/4/1975 0:00  1975      1    4        240.5
# 4        1/5/1975 0:00  1975      1    5         18.1
# ...                ...   ...    ...  ...          ...
# 15690  12/27/2017 0:00  2017     12   27          2.6
# 15691  12/28/2017 0:00  2017     12   28         20.6
# 15692  12/29/2017 0:00  2017     12   29         49.4
# 15693  12/30/2017 0:00  2017     12   30         14.4
# 15694  12/31/2017 0:00  2017     12   31         61.4
#
# [15695 rows x 5 columns]
#             Date  Year  Month  Day  KUANTAN[mm]
# 0  1/1/1975 0:00  1975      1    1          0.5
# 1  1/2/1975 0:00  1975      1    2        131.3
# 2  1/3/1975 0:00  1975      1    3         10.8
# 3  1/4/1975 0:00  1975      1    4        240.5
# 4  1/5/1975 0:00  1975      1    5         18.1

# %% [markdown]
# **With** **Normalization**

# %%
dataset = df.loc[:,'KUANTAN[mm]'].values
dataset = np.reshape(dataset,(-1,1))
print(dataset)
dataset.shape
# Out:
# [[  0.5]
#  [131.3]
#  [ 10.8]
#  ...
#  [ 49.4]
#  [ 14.4]
#  [ 61.4]]
# (15695, 1)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
print(dataset)
#train_size = int(len(dataset) * 0.80)
#test_size = len(dataset) - train_size
#train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
# Out:
# [[0.00094787]
#  [0.24890995]
#  [0.02047393]
#  ...
#  [0.09364929]
#  [0.02729858]
#  [0.1163981 ]]

# %%
#split into samples
from numpy import array

#14600/365 = 40
#sample = list(rain)

#split a univariate sequence into samples
def split_sequence(sequence, n_steps):
  x, y = list(), list()
  for i in range(len(sequence)):
    #find end of this pattern
    end_ix = i + n_steps
    #check if beyond the sequence
    if end_ix > len(sequence)-1:
      break
    #gather input and output parts of the pattern
    seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
    x.append(seq_x)
    y.append(seq_y)
  return array(x), array(y)

series = array(dataset)
print(series.shape)

x, y = split_sequence(series, 365)
print(x.shape, y.shape)
# Out:
# (15695, 1)
# (15330, 365, 1) (15330, 1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 0)
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (10731, 365, 1) (10731, 1)
# (4599, 365, 1) (4599, 1)

# %%
#reshape 
series1 = x_train.reshape(x_train.shape[0], x_train.shape[1], 1)
series2 = x_test.reshape(x_test.shape[0], x_test.shape[1], 1)
print(series1.shape)
print(series2.shape)
# Out:
# (10731, 365, 1)
# (4599, 365, 1)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense 
from keras.layers import Dropout
from keras.layers import LSTM
from keras.optimizers import SGD
import keras.backend as K
from keras.callbacks import EarlyStopping
# Out:
# Using TensorFlow backend.

# %% [markdown]
# **batch size for series1 = 2, 4, 53, 94, 106, 188, 2491, 4982**
#
# **batch size for series2 = 4271 is a prime number**

# %%
K.clear_session()
model = Sequential()
model.add(LSTM(13, return_sequences=True, input_shape=(365, 1)))
model.add(LSTM(4))
#model.add(Dropout(0.1))
model.add(Dense(1))

#opt = keras.optimizers.Adam(learning_rate=1e-1000)
#opt = optimizers.adam(clipnorm=1.0)
#opt = SGD(lr=0.01, momentum=0.9, clipnorm=1.0)
model.compile(loss='mean_squared_error', optimizer='adam')


history = model.fit(series1, y_train, epochs=500, batch_size=100, validation_data=(series2, y_test),
                   callbacks=[EarlyStopping(monitor='val_loss', patience=10)], verbose=1, shuffle=False)

model.summary()
# Out:
# Train on 10731 samples, validate on 4599 samples
# Epoch 1/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 2/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 3/500
# 10731/10731 [==============================] - 20s 2ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 4/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 5/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 6/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 7/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 8/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 9/500
# 10731/10731 [==============================] - 20s 2ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 10/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 11/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 12/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 13/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 14/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 15/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 16/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 17/500
# 10731/10731 [==============================] - 20s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 18/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 19/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 20/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 21/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 22/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 23/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 24/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 25/500
# 10731/10731 [==============================] - 24s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 26/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 27/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 28/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 29/500
# 10731/10731 [==============================] - 20s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 30/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 31/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 32/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 33/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 34/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 365, 13)           780
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 4)                 288
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 1,073
# Trainable params: 1,073
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Make Predictions**

# %%
import math
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

train_predict = model.predict(series1)
test_predict = model.predict(series2)
# invert predictions
train_predict = scaler.inverse_transform(train_predict)
y_train = scaler.inverse_transform(y_train)
test_predict = scaler.inverse_transform(test_predict)
y_test = scaler.inverse_transform(y_test)

# %%
print('Train Mean Absolute Error:', mean_absolute_error(y_train[:,0], train_predict[:,0]))
print('Train Root Mean Squared Error:',np.sqrt(mean_squared_error(y_train[:,0], train_predict[:,0])))
print('Test Mean Absolute Error:', mean_absolute_error(y_test[:,0], test_predict[:,0]))
print('Test Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test[:,0], test_predict[:,0])))
# Out:
# Train Mean Absolute Error: 10.599729964331205
# Train Root Mean Squared Error: 19.657653296891578
# Test Mean Absolute Error: 10.631959719781282
# Test Root Mean Squared Error: 20.94250764034597

# %%
import matplotlib.pyplot as plt
#plot model loss

plt.figure(figsize=(8,4))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend(loc='upper right')
plt.show();

# %%
#actual vs prediction

import seaborn as sns

aa=[x for x in range(200)]
plt.figure(figsize=(12,6))
plt.plot(aa, y_test[:,0][:200], marker='.', label="actual")
plt.plot(aa, test_predict[:,0][:200], 'r', label="prediction")
# plt.tick_params(left=False, labelleft=True) #remove ticks
plt.tight_layout()
sns.despine(top=True)
plt.subplots_adjust(left=0.07)
plt.title('Kuala Krai Station', size=15)
plt.ylabel('Rainfall Amount (mm)', size=15)
plt.xlabel('Time step', size=15)
plt.legend(fontsize=15)
plt.show();

# %%
print(test_predict.shape)
print(y_test.shape)

a = plt.axes(aspect='equal')
plt.scatter(y_test, test_predict)
plt.xlabel('True Values')
plt.ylabel('Predictions')
lims = [0, 320]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)
# Out:
# (4599, 1)
# (4599, 1)

# %%
import scipy.stats as measures

per_coef = measures.pearsonr(y_test[:,0], test_predict[:,0])
#mse_coef = np.mean(np.square(np.array(y_pred) - np.array(y_true)))
print(per_coef)
# Out:
# (0.31981197406194206, 7.23860677153221e-110)

# %%
per_coef1 = measures.pearsonr(y_train[:,0], train_predict[:,0])
print(per_coef1)
# Out:
# (0.34026530310792535, 4.744384189368593e-289)

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# # Stacked LSTM

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['Kuantan1975-2017New.csv']))
print(df,sep=',')
df.head()
# Out:
#                   Date  Year  Month  Day  KUANTAN[mm]
# 0        1/1/1975 0:00  1975      1    1          0.5
# 1        1/2/1975 0:00  1975      1    2        131.3
# 2        1/3/1975 0:00  1975      1    3         10.8
# 3        1/4/1975 0:00  1975      1    4        240.5
# 4        1/5/1975 0:00  1975      1    5         18.1
# ...                ...   ...    ...  ...          ...
# 15690  12/27/2017 0:00  2017     12   27          2.6
# 15691  12/28/2017 0:00  2017     12   28         20.6
# 15692  12/29/2017 0:00  2017     12   29         49.4
# 15693  12/30/2017 0:00  2017     12   30         14.4
# 15694  12/31/2017 0:00  2017     12   31         61.4
#
# [15695 rows x 5 columns]
#             Date  Year  Month  Day  KUANTAN[mm]
# 0  1/1/1975 0:00  1975      1    1          0.5
# 1  1/2/1975 0:00  1975      1    2        131.3
# 2  1/3/1975 0:00  1975      1    3         10.8
# 3  1/4/1975 0:00  1975      1    4        240.5
# 4  1/5/1975 0:00  1975      1    5         18.1

# %% [markdown]
# **With** **Normalization**

# %%
dataset = df.loc[:,'KUANTAN[mm]'].values
dataset = np.reshape(dataset,(-1,1))
print(dataset)
dataset.shape
# Out:
# [[  0.5]
#  [131.3]
#  [ 10.8]
#  ...
#  [ 49.4]
#  [ 14.4]
#  [ 61.4]]
# (15695, 1)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
print(dataset)
#train_size = int(len(dataset) * 0.80)
#test_size = len(dataset) - train_size
#train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
# Out:
# [[0.00094787]
#  [0.24890995]
#  [0.02047393]
#  ...
#  [0.09364929]
#  [0.02729858]
#  [0.1163981 ]]

# %%
#split into samples
from numpy import array

#14600/365 = 40
#sample = list(rain)

#split a univariate sequence into samples
def split_sequence(sequence, n_steps):
  x, y = list(), list()
  for i in range(len(sequence)):
    #find end of this pattern
    end_ix = i + n_steps
    #check if beyond the sequence
    if end_ix > len(sequence)-1:
      break
    #gather input and output parts of the pattern
    seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
    x.append(seq_x)
    y.append(seq_y)
  return array(x), array(y)

series = array(dataset)
print(series.shape)

x, y = split_sequence(series, 365)
print(x.shape, y.shape)
# Out:
# (15695, 1)
# (15330, 365, 1) (15330, 1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 0)
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (10731, 365, 1) (10731, 1)
# (4599, 365, 1) (4599, 1)

# %%
#reshape 
series1 = x_train.reshape(x_train.shape[0], x_train.shape[1], 1)
series2 = x_test.reshape(x_test.shape[0], x_test.shape[1], 1)
print(series1.shape)
print(series2.shape)
# Out:
# (10731, 365, 1)
# (4599, 365, 1)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense 
from keras.layers import Dropout
from keras.layers import LSTM
from keras.optimizers import SGD
import keras.backend as K
from keras.callbacks import EarlyStopping
# Out:
# Using TensorFlow backend.

# %% [markdown]
# **batch size for series1 = 2, 4, 53, 94, 106, 188, 2491, 4982**
#
# **batch size for series2 = 4271 is a prime number**

# %%
K.clear_session()
model = Sequential()
model.add(LSTM(4, return_sequences=True, input_shape=(365, 1)))
model.add(LSTM(3))
#model.add(Dropout(0.1))
model.add(Dense(1))

#opt = keras.optimizers.Adam(learning_rate=1e-1000)
#opt = optimizers.adam(clipnorm=1.0)
#opt = SGD(lr=0.01, momentum=0.9, clipnorm=1.0)
model.compile(loss='mean_squared_error', optimizer='adam')


history = model.fit(series1, y_train, epochs=500, batch_size=100, validation_data=(series2, y_test),
                   callbacks=[EarlyStopping(monitor='val_loss', patience=10)], verbose=1, shuffle=False)

model.summary()
# Out:
# Train on 10731 samples, validate on 4599 samples
# Epoch 1/500
# 10731/10731 [==============================] - 31s 3ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 2/500
# 10731/10731 [==============================] - 29s 3ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 3/500
# 10731/10731 [==============================] - 28s 3ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 4/500
# 10731/10731 [==============================] - 28s 3ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 5/500
# 10731/10731 [==============================] - 28s 3ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 6/500
# 10731/10731 [==============================] - 28s 3ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 7/500
# 10731/10731 [==============================] - 28s 3ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 8/500
# 10731/10731 [==============================] - 25s 2ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 9/500
# 10731/10731 [==============================] - 25s 2ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 10/500
# 10731/10731 [==============================] - 25s 2ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 11/500
# 10731/10731 [==============================] - 25s 2ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 12/500
# 10731/10731 [==============================] - 24s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 13/500
# 10731/10731 [==============================] - 24s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 14/500
# 10731/10731 [==============================] - 25s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 15/500
# 10731/10731 [==============================] - 24s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 16/500
# 10731/10731 [==============================] - 24s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 17/500
# 10731/10731 [==============================] - 24s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 18/500
# 10731/10731 [==============================] - 24s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 19/500
# 10731/10731 [==============================] - 25s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 20/500
# 10731/10731 [==============================] - 25s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 21/500
# 10731/10731 [==============================] - 24s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 22/500
# 10731/10731 [==============================] - 24s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 23/500
# 10731/10731 [==============================] - 25s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 24/500
# 10731/10731 [==============================] - 25s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 25/500
# 10731/10731 [==============================] - 25s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 26/500
# 10731/10731 [==============================] - 24s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 27/500
# 10731/10731 [==============================] - 24s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 28/500
# 10731/10731 [==============================] - 25s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 29/500
# 10731/10731 [==============================] - 25s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 30/500
# 10731/10731 [==============================] - 25s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 31/500
# 10731/10731 [==============================] - 25s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 32/500
# 10731/10731 [==============================] - 24s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 33/500
# 10731/10731 [==============================] - 24s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 34/500
# 10731/10731 [==============================] - 25s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 365, 4)            96
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 3)                 96
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 4
# =================================================================
# Total params: 196
# Trainable params: 196
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Make Predictions**

# %%
import math
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

train_predict = model.predict(series1)
test_predict = model.predict(series2)
# invert predictions
train_predict = scaler.inverse_transform(train_predict)
y_train = scaler.inverse_transform(y_train)
test_predict = scaler.inverse_transform(test_predict)
y_test = scaler.inverse_transform(y_test)

# %%
print('Train Mean Absolute Error:', mean_absolute_error(y_train[:,0], train_predict[:,0]))
print('Train Root Mean Squared Error:',np.sqrt(mean_squared_error(y_train[:,0], train_predict[:,0])))
print('Test Mean Absolute Error:', mean_absolute_error(y_test[:,0], test_predict[:,0]))
print('Test Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test[:,0], test_predict[:,0])))
# Out:
# Train Mean Absolute Error: 11.238290881959516
# Train Root Mean Squared Error: 19.762546718860904
# Test Mean Absolute Error: 11.195755857590827
# Test Root Mean Squared Error: 20.95076489904066

# %%
import matplotlib.pyplot as plt
#plot model loss

plt.figure(figsize=(8,4))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend(loc='upper right')
plt.show();

# %%
#actual vs prediction

import seaborn as sns

aa=[x for x in range(200)]
plt.figure(figsize=(12,6))
plt.plot(aa, y_test[:,0][:200], marker='.', label="actual")
plt.plot(aa, test_predict[:,0][:200], 'r', label="prediction")
# plt.tick_params(left=False, labelleft=True) #remove ticks
plt.tight_layout()
sns.despine(top=True)
plt.subplots_adjust(left=0.07)
plt.title('Kuala Krai Station', size=15)
plt.ylabel('Rainfall Amount (mm)', size=15)
plt.xlabel('Time step', size=15)
plt.legend(fontsize=15)
plt.show();

# %%
print(test_predict.shape)
print(y_test.shape)

a = plt.axes(aspect='equal')
plt.scatter(y_test, test_predict)
plt.xlabel('True Values')
plt.ylabel('Predictions')
lims = [0, 320]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)
# Out:
# (4599, 1)
# (4599, 1)

# %%
import scipy.stats as measures

per_coef = measures.pearsonr(y_test[:,0], test_predict[:,0])
#mse_coef = np.mean(np.square(np.array(y_pred) - np.array(y_true)))
print(per_coef)
# Out:
# (0.3244027655268755, 3.626605358206488e-113)

# %%
per_coef1 = measures.pearsonr(y_train[:,0], train_predict[:,0])
print(per_coef1)
# Out:
# (0.33434564617312745, 1.5213286822688267e-278)

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# # Stacked LSTM

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['Kuantan1975-2017New.csv']))
print(df,sep=',')
df.head()
# Out:
#                   Date  Year  Month  Day  KUANTAN[mm]
# 0        1/1/1975 0:00  1975      1    1          0.5
# 1        1/2/1975 0:00  1975      1    2        131.3
# 2        1/3/1975 0:00  1975      1    3         10.8
# 3        1/4/1975 0:00  1975      1    4        240.5
# 4        1/5/1975 0:00  1975      1    5         18.1
# ...                ...   ...    ...  ...          ...
# 15690  12/27/2017 0:00  2017     12   27          2.6
# 15691  12/28/2017 0:00  2017     12   28         20.6
# 15692  12/29/2017 0:00  2017     12   29         49.4
# 15693  12/30/2017 0:00  2017     12   30         14.4
# 15694  12/31/2017 0:00  2017     12   31         61.4
#
# [15695 rows x 5 columns]
#             Date  Year  Month  Day  KUANTAN[mm]
# 0  1/1/1975 0:00  1975      1    1          0.5
# 1  1/2/1975 0:00  1975      1    2        131.3
# 2  1/3/1975 0:00  1975      1    3         10.8
# 3  1/4/1975 0:00  1975      1    4        240.5
# 4  1/5/1975 0:00  1975      1    5         18.1

# %% [markdown]
# **With** **Normalization**

# %%
dataset = df.loc[:,'KUANTAN[mm]'].values
dataset = np.reshape(dataset,(-1,1))
print(dataset)
dataset.shape
# Out:
# [[  0.5]
#  [131.3]
#  [ 10.8]
#  ...
#  [ 49.4]
#  [ 14.4]
#  [ 61.4]]
# (15695, 1)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
print(dataset)
#train_size = int(len(dataset) * 0.80)
#test_size = len(dataset) - train_size
#train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
# Out:
# [[0.00094787]
#  [0.24890995]
#  [0.02047393]
#  ...
#  [0.09364929]
#  [0.02729858]
#  [0.1163981 ]]

# %%
#split into samples
from numpy import array

#14600/365 = 40
#sample = list(rain)

#split a univariate sequence into samples
def split_sequence(sequence, n_steps):
  x, y = list(), list()
  for i in range(len(sequence)):
    #find end of this pattern
    end_ix = i + n_steps
    #check if beyond the sequence
    if end_ix > len(sequence)-1:
      break
    #gather input and output parts of the pattern
    seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
    x.append(seq_x)
    y.append(seq_y)
  return array(x), array(y)

series = array(dataset)
print(series.shape)

x, y = split_sequence(series, 365)
print(x.shape, y.shape)
# Out:
# (15695, 1)
# (15330, 365, 1) (15330, 1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 0)
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (10731, 365, 1) (10731, 1)
# (4599, 365, 1) (4599, 1)

# %%
#reshape 
series1 = x_train.reshape(x_train.shape[0], x_train.shape[1], 1)
series2 = x_test.reshape(x_test.shape[0], x_test.shape[1], 1)
print(series1.shape)
print(series2.shape)
# Out:
# (10731, 365, 1)
# (4599, 365, 1)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense 
from keras.layers import Dropout
from keras.layers import LSTM
from keras.optimizers import SGD
import keras.backend as K
from keras.callbacks import EarlyStopping
# Out:
# Using TensorFlow backend.

# %% [markdown]
# **batch size for series1 = 2, 4, 53, 94, 106, 188, 2491, 4982**
#
# **batch size for series2 = 4271 is a prime number**

# %%
K.clear_session()
model = Sequential()
model.add(LSTM(8, return_sequences=True, input_shape=(365, 1)))
model.add(LSTM(5))
#model.add(Dropout(0.1))
model.add(Dense(1))

#opt = keras.optimizers.Adam(learning_rate=1e-1000)
#opt = optimizers.adam(clipnorm=1.0)
#opt = SGD(lr=0.01, momentum=0.9, clipnorm=1.0)
model.compile(loss='mean_squared_error', optimizer='adam')


history = model.fit(series1, y_train, epochs=500, batch_size=200, validation_data=(series2, y_test),
                   callbacks=[EarlyStopping(monitor='val_loss', patience=10)], verbose=1, shuffle=False)

model.summary()
# Out:
# Train on 10731 samples, validate on 4599 samples
# Epoch 1/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 2/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 3/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 4/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 5/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 6/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 7/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 8/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 9/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 10/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 11/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 12/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 13/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 14/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 15/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 16/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 17/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 18/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 19/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 20/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 21/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 22/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 23/500
# 10731/10731 [==============================] - 18s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 24/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 25/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 26/500
# 10731/10731 [==============================] - 18s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 27/500
# 10731/10731 [==============================] - 19s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 28/500
# 10731/10731 [==============================] - 18s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 29/500
# 10731/10731 [==============================] - 18s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 30/500
# 10731/10731 [==============================] - 18s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 31/500
# 10731/10731 [==============================] - 18s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 32/500
# 10731/10731 [==============================] - 18s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 33/500
# 10731/10731 [==============================] - 18s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 34/500
# 10731/10731 [==============================] - 18s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 35/500
# 10731/10731 [==============================] - 18s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 36/500
# 10731/10731 [==============================] - 18s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 37/500
# 10731/10731 [==============================] - 18s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 38/500
# 10731/10731 [==============================] - 18s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 39/500
# 10731/10731 [==============================] - 18s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 40/500
# 10731/10731 [==============================] - 18s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 41/500
# 10731/10731 [==============================] - 18s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 42/500
# 10731/10731 [==============================] - 18s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 43/500
# 10731/10731 [==============================] - 18s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 44/500
# 10731/10731 [==============================] - 18s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 45/500
# 10731/10731 [==============================] - 18s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 46/500
# 10731/10731 [==============================] - 18s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 47/500
# 10731/10731 [==============================] - 18s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 48/500
# 10731/10731 [==============================] - 18s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 49/500
# 10731/10731 [==============================] - 18s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 50/500
# 10731/10731 [==============================] - 18s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 51/500
# 10731/10731 [==============================] - 18s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 52/500
# 10731/10731 [==============================] - 18s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 365, 8)            320
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 5)                 280
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 606
# Trainable params: 606
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Make Predictions**

# %%
import math
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

train_predict = model.predict(series1)
test_predict = model.predict(series2)
# invert predictions
train_predict = scaler.inverse_transform(train_predict)
y_train = scaler.inverse_transform(y_train)
test_predict = scaler.inverse_transform(test_predict)
y_test = scaler.inverse_transform(y_test)

# %%
print('Train Mean Absolute Error:', mean_absolute_error(y_train[:,0], train_predict[:,0]))
print('Train Root Mean Squared Error:',np.sqrt(mean_squared_error(y_train[:,0], train_predict[:,0])))
print('Test Mean Absolute Error:', mean_absolute_error(y_test[:,0], test_predict[:,0]))
print('Test Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test[:,0], test_predict[:,0])))
# Out:
# Train Mean Absolute Error: 10.659156846746841
# Train Root Mean Squared Error: 19.675939466110897
# Test Mean Absolute Error: 10.653618704248808
# Test Root Mean Squared Error: 20.89464918037906

# %%
import matplotlib.pyplot as plt
#plot model loss

plt.figure(figsize=(8,4))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend(loc='upper right')
plt.show();

# %%
#actual vs prediction

import seaborn as sns

aa=[x for x in range(200)]
plt.figure(figsize=(12,6))
plt.plot(aa, y_test[:,0][:200], marker='.', label="actual")
plt.plot(aa, test_predict[:,0][:200], 'r', label="prediction")
# plt.tick_params(left=False, labelleft=True) #remove ticks
plt.tight_layout()
sns.despine(top=True)
plt.subplots_adjust(left=0.07)
plt.title('Kuala Krai Station', size=15)
plt.ylabel('Rainfall Amount (mm)', size=15)
plt.xlabel('Time step', size=15)
plt.legend(fontsize=15)
plt.show();

# %%
print(test_predict.shape)
print(y_test.shape)

a = plt.axes(aspect='equal')
plt.scatter(y_test, test_predict)
plt.xlabel('True Values')
plt.ylabel('Predictions')
lims = [0, 320]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)
# Out:
# (4599, 1)
# (4599, 1)

# %%
import scipy.stats as measures

per_coef = measures.pearsonr(y_test[:,0], test_predict[:,0])
#mse_coef = np.mean(np.square(np.array(y_pred) - np.array(y_true)))
print(per_coef)
# Out:
# (0.32601001094113147, 2.4571380512910155e-114)

# %%
per_coef1 = measures.pearsonr(y_train[:,0], train_predict[:,0])
print(per_coef1)
# Out:
# (0.33829425694805043, 1.585094622143259e-285)

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# # Stacked LSTM

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['Kuantan1975-2017New.csv']))
print(df,sep=',')
df.head()
# Out:
#                   Date  Year  Month  Day  KUANTAN[mm]
# 0        1/1/1975 0:00  1975      1    1          0.5
# 1        1/2/1975 0:00  1975      1    2        131.3
# 2        1/3/1975 0:00  1975      1    3         10.8
# 3        1/4/1975 0:00  1975      1    4        240.5
# 4        1/5/1975 0:00  1975      1    5         18.1
# ...                ...   ...    ...  ...          ...
# 15690  12/27/2017 0:00  2017     12   27          2.6
# 15691  12/28/2017 0:00  2017     12   28         20.6
# 15692  12/29/2017 0:00  2017     12   29         49.4
# 15693  12/30/2017 0:00  2017     12   30         14.4
# 15694  12/31/2017 0:00  2017     12   31         61.4
#
# [15695 rows x 5 columns]
#             Date  Year  Month  Day  KUANTAN[mm]
# 0  1/1/1975 0:00  1975      1    1          0.5
# 1  1/2/1975 0:00  1975      1    2        131.3
# 2  1/3/1975 0:00  1975      1    3         10.8
# 3  1/4/1975 0:00  1975      1    4        240.5
# 4  1/5/1975 0:00  1975      1    5         18.1

# %% [markdown]
# **With** **Normalization**

# %%
dataset = df.loc[:,'KUANTAN[mm]'].values
dataset = np.reshape(dataset,(-1,1))
print(dataset)
dataset.shape
# Out:
# [[  0.5]
#  [131.3]
#  [ 10.8]
#  ...
#  [ 49.4]
#  [ 14.4]
#  [ 61.4]]
# (15695, 1)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
print(dataset)
#train_size = int(len(dataset) * 0.80)
#test_size = len(dataset) - train_size
#train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
# Out:
# [[0.00094787]
#  [0.24890995]
#  [0.02047393]
#  ...
#  [0.09364929]
#  [0.02729858]
#  [0.1163981 ]]

# %%
#split into samples
from numpy import array

#14600/365 = 40
#sample = list(rain)

#split a univariate sequence into samples
def split_sequence(sequence, n_steps):
  x, y = list(), list()
  for i in range(len(sequence)):
    #find end of this pattern
    end_ix = i + n_steps
    #check if beyond the sequence
    if end_ix > len(sequence)-1:
      break
    #gather input and output parts of the pattern
    seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
    x.append(seq_x)
    y.append(seq_y)
  return array(x), array(y)

series = array(dataset)
print(series.shape)

x, y = split_sequence(series, 365)
print(x.shape, y.shape)
# Out:
# (15695, 1)
# (15330, 365, 1) (15330, 1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 0)
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (10731, 365, 1) (10731, 1)
# (4599, 365, 1) (4599, 1)

# %%
#reshape 
series1 = x_train.reshape(x_train.shape[0], x_train.shape[1], 1)
series2 = x_test.reshape(x_test.shape[0], x_test.shape[1], 1)
print(series1.shape)
print(series2.shape)
# Out:
# (10731, 365, 1)
# (4599, 365, 1)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense 
from keras.layers import Dropout
from keras.layers import LSTM
from keras.optimizers import SGD
import keras.backend as K
from keras.callbacks import EarlyStopping

# %% [markdown]
# **batch size for series1 = 2, 4, 53, 94, 106, 188, 2491, 4982**
#
# **batch size for series2 = 4271 is a prime number**

# %%
K.clear_session()
model = Sequential()
model.add(LSTM(16, return_sequences=True, input_shape=(365, 1)))
model.add(LSTM(10))
#model.add(Dropout(0.1))
model.add(Dense(1))

#opt = keras.optimizers.Adam(learning_rate=1e-1000)
#opt = optimizers.adam(clipnorm=1.0)
#opt = SGD(lr=0.01, momentum=0.9, clipnorm=1.0)
model.compile(loss='mean_squared_error', optimizer='adam')


history = model.fit(series1, y_train, epochs=500, batch_size=100, validation_data=(series2, y_test),
                   callbacks=[EarlyStopping(monitor='val_loss', patience=10)], verbose=1, shuffle=False)

model.summary()
# Out:
# Train on 10731 samples, validate on 4599 samples
# Epoch 1/500
# 10731/10731 [==============================] - 38s 4ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 2/500
# 10731/10731 [==============================] - 38s 4ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 3/500
# 10731/10731 [==============================] - 39s 4ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 4/500
# 10731/10731 [==============================] - 38s 4ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 5/500
# 10731/10731 [==============================] - 38s 4ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 6/500
# 10731/10731 [==============================] - 38s 4ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 7/500
# 10731/10731 [==============================] - 38s 4ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 8/500
# 10731/10731 [==============================] - 39s 4ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 9/500
# 10731/10731 [==============================] - 38s 4ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 10/500
# 10731/10731 [==============================] - 38s 4ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 11/500
# 10731/10731 [==============================] - 41s 4ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 12/500
# 10731/10731 [==============================] - 42s 4ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 13/500
# 10731/10731 [==============================] - 41s 4ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 14/500
# 10731/10731 [==============================] - 41s 4ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 15/500
# 10731/10731 [==============================] - 42s 4ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 16/500
# 10731/10731 [==============================] - 43s 4ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 17/500
# 10731/10731 [==============================] - 42s 4ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 18/500
# 10731/10731 [==============================] - 42s 4ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 19/500
# 10731/10731 [==============================] - 42s 4ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 20/500
# 10731/10731 [==============================] - 42s 4ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 21/500
# 10731/10731 [==============================] - 42s 4ms/step - loss: 0.0014 - val_loss: 0.0016
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 365, 16)           1152
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 10)                1080
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 2,243
# Trainable params: 2,243
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Make Predictions**

# %%
import math
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

train_predict = model.predict(series1)
test_predict = model.predict(series2)
# invert predictions
train_predict = scaler.inverse_transform(train_predict)
y_train = scaler.inverse_transform(y_train)
test_predict = scaler.inverse_transform(test_predict)
y_test = scaler.inverse_transform(y_test)

# %%
print('Train Mean Absolute Error:', mean_absolute_error(y_train[:,0], train_predict[:,0]))
print('Train Root Mean Squared Error:',np.sqrt(mean_squared_error(y_train[:,0], train_predict[:,0])))
print('Test Mean Absolute Error:', mean_absolute_error(y_test[:,0], test_predict[:,0]))
print('Test Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test[:,0], test_predict[:,0])))
# Out:
# Train Mean Absolute Error: 10.297079576875875
# Train Root Mean Squared Error: 19.67913715088829
# Test Mean Absolute Error: 10.316509230734605
# Test Root Mean Squared Error: 20.936962663329762

# %%
import matplotlib.pyplot as plt
#plot model loss

plt.figure(figsize=(8,4))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend(loc='upper right')
plt.show();

# %%
#actual vs prediction

import seaborn as sns

aa=[x for x in range(200)]
plt.figure(figsize=(12,6))
plt.plot(aa, y_test[:,0][:200], marker='.', label="actual")
plt.plot(aa, test_predict[:,0][:200], 'r', label="prediction")
# plt.tick_params(left=False, labelleft=True) #remove ticks
plt.tight_layout()
sns.despine(top=True)
plt.subplots_adjust(left=0.07)
plt.title('Kuala Krai Station', size=15)
plt.ylabel('Rainfall Amount (mm)', size=15)
plt.xlabel('Time step', size=15)
plt.legend(fontsize=15)
plt.show();

# %%
print(test_predict.shape)
print(y_test.shape)

a = plt.axes(aspect='equal')
plt.scatter(y_test, test_predict)
plt.xlabel('True Values')
plt.ylabel('Predictions')
lims = [0, 320]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)
# Out:
# (4599, 1)
# (4599, 1)

# %%
import scipy.stats as measures

per_coef = measures.pearsonr(y_test[:,0], test_predict[:,0])
#mse_coef = np.mean(np.square(np.array(y_pred) - np.array(y_true)))
print(per_coef)
# Out:
# (0.3200241928118611, 5.109394363624178e-110)

# %%
per_coef1 = measures.pearsonr(y_train[:,0], train_predict[:,0])
print(per_coef1)
# Out:
# (0.336291220386174, 5.685701693190337e-282)

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# # Stacked LSTM

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['Kuantan1975-2017New.csv']))
print(df,sep=',')
df.head()
# Out:
#                   Date  Year  Month  Day  KUANTAN[mm]
# 0        1/1/1975 0:00  1975      1    1          0.5
# 1        1/2/1975 0:00  1975      1    2        131.3
# 2        1/3/1975 0:00  1975      1    3         10.8
# 3        1/4/1975 0:00  1975      1    4        240.5
# 4        1/5/1975 0:00  1975      1    5         18.1
# ...                ...   ...    ...  ...          ...
# 15690  12/27/2017 0:00  2017     12   27          2.6
# 15691  12/28/2017 0:00  2017     12   28         20.6
# 15692  12/29/2017 0:00  2017     12   29         49.4
# 15693  12/30/2017 0:00  2017     12   30         14.4
# 15694  12/31/2017 0:00  2017     12   31         61.4
#
# [15695 rows x 5 columns]
#             Date  Year  Month  Day  KUANTAN[mm]
# 0  1/1/1975 0:00  1975      1    1          0.5
# 1  1/2/1975 0:00  1975      1    2        131.3
# 2  1/3/1975 0:00  1975      1    3         10.8
# 3  1/4/1975 0:00  1975      1    4        240.5
# 4  1/5/1975 0:00  1975      1    5         18.1

# %% [markdown]
# **With** **Normalization**

# %%
dataset = df.loc[:,'KUANTAN[mm]'].values
dataset = np.reshape(dataset,(-1,1))
print(dataset)
dataset.shape
# Out:
# [[  0.5]
#  [131.3]
#  [ 10.8]
#  ...
#  [ 49.4]
#  [ 14.4]
#  [ 61.4]]
# (15695, 1)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
print(dataset)
#train_size = int(len(dataset) * 0.80)
#test_size = len(dataset) - train_size
#train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
# Out:
# [[0.00094787]
#  [0.24890995]
#  [0.02047393]
#  ...
#  [0.09364929]
#  [0.02729858]
#  [0.1163981 ]]

# %%
#split into samples
from numpy import array

#14600/365 = 40
#sample = list(rain)

#split a univariate sequence into samples
def split_sequence(sequence, n_steps):
  x, y = list(), list()
  for i in range(len(sequence)):
    #find end of this pattern
    end_ix = i + n_steps
    #check if beyond the sequence
    if end_ix > len(sequence)-1:
      break
    #gather input and output parts of the pattern
    seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
    x.append(seq_x)
    y.append(seq_y)
  return array(x), array(y)

series = array(dataset)
print(series.shape)

x, y = split_sequence(series, 365)
print(x.shape, y.shape)
# Out:
# (15695, 1)
# (15330, 365, 1) (15330, 1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 0)
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (10731, 365, 1) (10731, 1)
# (4599, 365, 1) (4599, 1)

# %%
#reshape 
series1 = x_train.reshape(x_train.shape[0], x_train.shape[1], 1)
series2 = x_test.reshape(x_test.shape[0], x_test.shape[1], 1)
print(series1.shape)
print(series2.shape)
# Out:
# (10731, 365, 1)
# (4599, 365, 1)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense 
from keras.layers import Dropout
from keras.layers import LSTM
from keras.optimizers import SGD
import keras.backend as K
from keras.callbacks import EarlyStopping

# %% [markdown]
# **batch size for series1 = 2, 4, 53, 94, 106, 188, 2491, 4982**
#
# **batch size for series2 = 4271 is a prime number**

# %%
K.clear_session()
model = Sequential()
model.add(LSTM(32, return_sequences=True, input_shape=(365, 1)))
model.add(LSTM(20))
#model.add(Dropout(0.1))
model.add(Dense(1))

#opt = keras.optimizers.Adam(learning_rate=1e-1000)
#opt = optimizers.adam(clipnorm=1.0)
#opt = SGD(lr=0.01, momentum=0.9, clipnorm=1.0)
model.compile(loss='mean_squared_error', optimizer='adam')


history = model.fit(series1, y_train, epochs=500, batch_size=100, validation_data=(series2, y_test),
                   callbacks=[EarlyStopping(monitor='val_loss', patience=10)], verbose=1, shuffle=False)

model.summary()
# Out:
# Train on 10731 samples, validate on 4599 samples
# Epoch 1/500
# 10731/10731 [==============================] - 47s 4ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 2/500
# 10731/10731 [==============================] - 47s 4ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 3/500
# 10731/10731 [==============================] - 47s 4ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 4/500
# 10731/10731 [==============================] - 46s 4ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 5/500
# 10731/10731 [==============================] - 47s 4ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 6/500
# 10731/10731 [==============================] - 47s 4ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 7/500
# 10731/10731 [==============================] - 47s 4ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 8/500
# 10731/10731 [==============================] - 47s 4ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 9/500
# 10731/10731 [==============================] - 50s 5ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 10/500
# 10731/10731 [==============================] - 50s 5ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 11/500
# 10731/10731 [==============================] - 50s 5ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 12/500
# 10731/10731 [==============================] - 50s 5ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 13/500
# 10731/10731 [==============================] - 50s 5ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 14/500
# 10731/10731 [==============================] - 50s 5ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 15/500
# 10731/10731 [==============================] - 49s 5ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 16/500
# 10731/10731 [==============================] - 51s 5ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 17/500
# 10731/10731 [==============================] - 50s 5ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 18/500
# 10731/10731 [==============================] - 50s 5ms/step - loss: 0.0014 - val_loss: 0.0016
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 365, 32)           4352
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 20)                4240
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 8,613
# Trainable params: 8,613
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Make Predictions**

# %%
import math
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

train_predict = model.predict(series1)
test_predict = model.predict(series2)
# invert predictions
train_predict = scaler.inverse_transform(train_predict)
y_train = scaler.inverse_transform(y_train)
test_predict = scaler.inverse_transform(test_predict)
y_test = scaler.inverse_transform(y_test)

# %%
print('Train Mean Absolute Error:', mean_absolute_error(y_train[:,0], train_predict[:,0]))
print('Train Root Mean Squared Error:',np.sqrt(mean_squared_error(y_train[:,0], train_predict[:,0])))
print('Test Mean Absolute Error:', mean_absolute_error(y_test[:,0], test_predict[:,0]))
print('Test Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test[:,0], test_predict[:,0])))
# Out:
# Train Mean Absolute Error: 9.994020694033784
# Train Root Mean Squared Error: 19.691992909903643
# Test Mean Absolute Error: 10.029751963033757
# Test Root Mean Squared Error: 20.948157722822934

# %%
import matplotlib.pyplot as plt
#plot model loss

plt.figure(figsize=(8,4))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend(loc='upper right')
plt.show();

# %%
#actual vs prediction

import seaborn as sns

aa=[x for x in range(200)]
plt.figure(figsize=(12,6))
plt.plot(aa, y_test[:,0][:200], marker='.', label="actual")
plt.plot(aa, test_predict[:,0][:200], 'r', label="prediction")
# plt.tick_params(left=False, labelleft=True) #remove ticks
plt.tight_layout()
sns.despine(top=True)
plt.subplots_adjust(left=0.07)
plt.title('Kuala Krai Station', size=15)
plt.ylabel('Rainfall Amount (mm)', size=15)
plt.xlabel('Time step', size=15)
plt.legend(fontsize=15)
plt.show();

# %%
print(test_predict.shape)
print(y_test.shape)

a = plt.axes(aspect='equal')
plt.scatter(y_test, test_predict)
plt.xlabel('True Values')
plt.ylabel('Predictions')
lims = [0, 320]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)
# Out:
# (4599, 1)
# (4599, 1)

# %%
import scipy.stats as measures

per_coef = measures.pearsonr(y_test[:,0], test_predict[:,0])
#mse_coef = np.mean(np.square(np.array(y_pred) - np.array(y_true)))
print(per_coef)
# Out:
# (0.3200300729834052, 5.0602951112419627e-110)

# %%
per_coef1 = measures.pearsonr(y_train[:,0], train_predict[:,0])
print(per_coef1)
# Out:
# (0.33564939179772224, 7.73071075635158e-281)

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# # Stacked LSTM

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['Kuantan1975-2017New.csv']))
print(df,sep=',')
df.head()
# Out:
#                   Date  Year  Month  Day  KUANTAN[mm]
# 0        1/1/1975 0:00  1975      1    1          0.5
# 1        1/2/1975 0:00  1975      1    2        131.3
# 2        1/3/1975 0:00  1975      1    3         10.8
# 3        1/4/1975 0:00  1975      1    4        240.5
# 4        1/5/1975 0:00  1975      1    5         18.1
# ...                ...   ...    ...  ...          ...
# 15690  12/27/2017 0:00  2017     12   27          2.6
# 15691  12/28/2017 0:00  2017     12   28         20.6
# 15692  12/29/2017 0:00  2017     12   29         49.4
# 15693  12/30/2017 0:00  2017     12   30         14.4
# 15694  12/31/2017 0:00  2017     12   31         61.4
#
# [15695 rows x 5 columns]
#             Date  Year  Month  Day  KUANTAN[mm]
# 0  1/1/1975 0:00  1975      1    1          0.5
# 1  1/2/1975 0:00  1975      1    2        131.3
# 2  1/3/1975 0:00  1975      1    3         10.8
# 3  1/4/1975 0:00  1975      1    4        240.5
# 4  1/5/1975 0:00  1975      1    5         18.1

# %% [markdown]
# **With** **Normalization**

# %%
dataset = df.loc[:,'KUANTAN[mm]'].values
dataset = np.reshape(dataset,(-1,1))
print(dataset)
dataset.shape
# Out:
# [[  0.5]
#  [131.3]
#  [ 10.8]
#  ...
#  [ 49.4]
#  [ 14.4]
#  [ 61.4]]
# (15695, 1)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
print(dataset)
#train_size = int(len(dataset) * 0.80)
#test_size = len(dataset) - train_size
#train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
# Out:
# [[0.00094787]
#  [0.24890995]
#  [0.02047393]
#  ...
#  [0.09364929]
#  [0.02729858]
#  [0.1163981 ]]

# %%
#split into samples
from numpy import array

#14600/365 = 40
#sample = list(rain)

#split a univariate sequence into samples
def split_sequence(sequence, n_steps):
  x, y = list(), list()
  for i in range(len(sequence)):
    #find end of this pattern
    end_ix = i + n_steps
    #check if beyond the sequence
    if end_ix > len(sequence)-1:
      break
    #gather input and output parts of the pattern
    seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
    x.append(seq_x)
    y.append(seq_y)
  return array(x), array(y)

series = array(dataset)
print(series.shape)

x, y = split_sequence(series, 365)
print(x.shape, y.shape)
# Out:
# (15695, 1)
# (15330, 365, 1) (15330, 1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 0)
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (10731, 365, 1) (10731, 1)
# (4599, 365, 1) (4599, 1)

# %%
#reshape 
series1 = x_train.reshape(x_train.shape[0], x_train.shape[1], 1)
series2 = x_test.reshape(x_test.shape[0], x_test.shape[1], 1)
print(series1.shape)
print(series2.shape)
# Out:
# (10731, 365, 1)
# (4599, 365, 1)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense 
from keras.layers import Dropout
from keras.layers import LSTM
from keras.optimizers import SGD
import keras.backend as K
from keras.callbacks import EarlyStopping

# %% [markdown]
# **batch size for series1 = 2, 4, 53, 94, 106, 188, 2491, 4982**
#
# **batch size for series2 = 4271 is a prime number**

# %%
K.clear_session()
model = Sequential()
model.add(LSTM(64, return_sequences=True, input_shape=(365, 1)))
model.add(LSTM(50))
#model.add(Dropout(0.1))
model.add(Dense(1))

#opt = keras.optimizers.Adam(learning_rate=1e-1000)
#opt = optimizers.adam(clipnorm=1.0)
#opt = SGD(lr=0.01, momentum=0.9, clipnorm=1.0)
model.compile(loss='mean_squared_error', optimizer='adam')


history = model.fit(series1, y_train, epochs=500, batch_size=100, validation_data=(series2, y_test),
                   callbacks=[EarlyStopping(monitor='val_loss', patience=10)], verbose=1, shuffle=False)

model.summary()
# Out:
# Train on 10731 samples, validate on 4599 samples
# Epoch 1/500
# 10731/10731 [==============================] - 86s 8ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 2/500
# 10731/10731 [==============================] - 86s 8ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 3/500
# 10731/10731 [==============================] - 85s 8ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 4/500
# 10731/10731 [==============================] - 86s 8ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 5/500
# 10731/10731 [==============================] - 86s 8ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 6/500
# 10731/10731 [==============================] - 86s 8ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 7/500
# 10731/10731 [==============================] - 86s 8ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 8/500
# 10731/10731 [==============================] - 86s 8ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 9/500
# 10731/10731 [==============================] - 86s 8ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 10/500
# 10731/10731 [==============================] - 85s 8ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 11/500
# 10731/10731 [==============================] - 85s 8ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 12/500
# 10731/10731 [==============================] - 86s 8ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 13/500
# 10731/10731 [==============================] - 86s 8ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 14/500
# 10731/10731 [==============================] - 85s 8ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 15/500
# 10731/10731 [==============================] - 86s 8ms/step - loss: 0.0014 - val_loss: 0.0016
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 365, 64)           16896
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 50)                23000
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 39,947
# Trainable params: 39,947
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Make Predictions**

# %%
import math
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

train_predict = model.predict(series1)
test_predict = model.predict(series2)
# invert predictions
train_predict = scaler.inverse_transform(train_predict)
y_train = scaler.inverse_transform(y_train)
test_predict = scaler.inverse_transform(test_predict)
y_test = scaler.inverse_transform(y_test)

# %%
print('Train Mean Absolute Error:', mean_absolute_error(y_train[:,0], train_predict[:,0]))
print('Train Root Mean Squared Error:',np.sqrt(mean_squared_error(y_train[:,0], train_predict[:,0])))
print('Test Mean Absolute Error:', mean_absolute_error(y_test[:,0], test_predict[:,0]))
print('Test Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test[:,0], test_predict[:,0])))
# Out:
# Train Mean Absolute Error: 10.070754881254414
# Train Root Mean Squared Error: 19.70474910699214
# Test Mean Absolute Error: 10.09440340317703
# Test Root Mean Squared Error: 20.93831681539633

# %%
import matplotlib.pyplot as plt
#plot model loss

plt.figure(figsize=(8,4))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend(loc='upper right')
plt.show();

# %%
#actual vs prediction

import seaborn as sns

aa=[x for x in range(200)]
plt.figure(figsize=(12,6))
plt.plot(aa, y_test[:,0][:200], marker='.', label="actual")
plt.plot(aa, test_predict[:,0][:200], 'r', label="prediction")
# plt.tick_params(left=False, labelleft=True) #remove ticks
plt.tight_layout()
sns.despine(top=True)
plt.subplots_adjust(left=0.07)
plt.title('Kuala Krai Station', size=15)
plt.ylabel('Rainfall Amount (mm)', size=15)
plt.xlabel('Time step', size=15)
plt.legend(fontsize=15)
plt.show();

# %%
print(test_predict.shape)
print(y_test.shape)

a = plt.axes(aspect='equal')
plt.scatter(y_test, test_predict)
plt.xlabel('True Values')
plt.ylabel('Predictions')
lims = [0, 320]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)
# Out:
# (4599, 1)
# (4599, 1)

# %%
import scipy.stats as measures

per_coef = measures.pearsonr(y_test[:,0], test_predict[:,0])
#mse_coef = np.mean(np.square(np.array(y_pred) - np.array(y_true)))
print(per_coef)
# Out:
# (0.3203409023996382, 3.0364520060314224e-110)

# %%
per_coef1 = measures.pearsonr(y_train[:,0], train_predict[:,0])
print(per_coef1)
# Out:
# (0.33366769410559605, 2.3480223596626667e-277)

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
